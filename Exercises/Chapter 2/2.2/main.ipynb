# %% [markdown]
# ## 2.2

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Q2

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["A", "B", "C"],
    "age": [20, 21, 22],
    "salary": [1000, 2000, 3000]
})

df["age"]
# Out:
# 0    20
# 1    21
# 2    22
# Name: age, dtype: int64
